# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
documents =[
    "I love pizzas",
    "Pizzas are the best",
    "I love pastas",
    "Pastas are the best pastas"
]

# %%
vectorizer = TfidfVectorizer()

# %%
x = vectorizer.fit_transform(documents)

# %%
print("vocabulary:", vectorizer.get_feature_names_out())
print("\nBag of Words Matrix\n", x.toarray())
# Out:
# vocabulary: ['are' 'best' 'love' 'pastas' 'pizzas' 'the']
#
# Bag of Words Matrix
#  [[0.         0.         0.70710678 0.         0.70710678 0.        ]
#  [0.5        0.5        0.         0.         0.5        0.5       ]
#  [0.         0.         0.70710678 0.70710678 0.         0.        ]
#  [0.37796447 0.37796447 0.         0.75592895 0.         0.37796447]]
